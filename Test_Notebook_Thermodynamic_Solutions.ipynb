# %% [markdown]
# #   **Library Thermodynamic Solutions**
#
# <div>
# <div style="text-align: justify;">The&nbsp;analysis&nbsp;of&nbsp;multicomponent&nbsp;systems&nbsp;leads&nbsp;to&nbsp;elucidate&nbsp;or&nbsp;in&nbsp;its&nbsp;effect&nbsp;to&nbsp;describe&nbsp;in&nbsp;an&nbsp;approximate&nbsp;way&nbsp;the&nbsp;different&nbsp;phenomena&nbsp;as&nbsp;molecular&nbsp;interactions&nbsp;between&nbsp;the&nbsp;components&nbsp;of&nbsp;a&nbsp;system.</div>
# <br />
# <div style="text-align: justify;">Understanding&nbsp;the&nbsp;behavior&nbsp;of&nbsp;these&nbsp;phenomena&nbsp;allows&nbsp;the&nbsp;development&nbsp;of&nbsp;theoretical&nbsp;models&nbsp;to&nbsp;predict&nbsp;the&nbsp;different&nbsp;properties&nbsp;of&nbsp;the&nbsp;system,&nbsp;generating&nbsp;computer&nbsp;tools&nbsp;that,&nbsp;in&nbsp;addition&nbsp;to&nbsp;facilitating&nbsp;the&nbsp;analysis,&nbsp;allow&nbsp;a&nbsp;better&nbsp;understanding&nbsp;of&nbsp;the&nbsp;different&nbsp;factors&nbsp;involved&nbsp;in&nbsp;the&nbsp;solution&nbsp;process.</div>
# <br />
# <div style="text-align: justify;">One&nbsp;of&nbsp;the&nbsp;most&nbsp;important&nbsp;properties&nbsp;is&nbsp;solubility,&nbsp;since&nbsp;it&nbsp;is&nbsp;one&nbsp;of&nbsp;the&nbsp;most&nbsp;important&nbsp;stages&nbsp;in&nbsp;the&nbsp;research&nbsp;and&nbsp;development&nbsp;of&nbsp;pharmaceutical&nbsp;products,&nbsp;since&nbsp;it&nbsp;affects&nbsp;the&nbsp;biopharmaceutical&nbsp;and&nbsp;pharmacokinetic&nbsp;characteristics&nbsp;of&nbsp;the&nbsp;pharmaceutical&nbsp;forms.&nbsp;It&nbsp;is,&nbsp;therefore,&nbsp;that&nbsp;one&nbsp;of&nbsp;the&nbsp;most&nbsp;important&nbsp;lines&nbsp;of&nbsp;research&nbsp;in&nbsp;solution&nbsp;thermodynamics&nbsp;are&nbsp;mathematical&nbsp;models&nbsp;that&nbsp;allow&nbsp;predicting&nbsp;solubility&nbsp;with&nbsp;very&nbsp;low&nbsp;error&nbsp;ranges.</div>
# <br />
# <div style="text-align: justify;">Thus,&nbsp;we&nbsp;present&nbsp;a&nbsp;computer&nbsp;tool&nbsp;in&nbsp;Python&nbsp;code&nbsp;that&nbsp;provides&nbsp;an&nbsp;easy&nbsp;way&nbsp;to&nbsp;evaluate&nbsp;the&nbsp;solubility&nbsp;behavior&nbsp;of&nbsp;drugs&nbsp;in&nbsp;cosolvent&nbsp;systems,&nbsp;according&nbsp;to&nbsp;different&nbsp;mathematical&nbsp;models.</div>
# </div>

# %% [markdown]
# ##  **Github repository cloning**

# %%
# !git clone https://github.com/SolubilityGroup/ThermodynamicSolutions
# Out:
# Cloning into 'ThermodynamicSolutions'...
# remote: Enumerating objects: 33, done.
# remote: Counting objects: 100% (33/33), done.
# remote: Compressing objects: 100% (27/27), done.
# remote: Total 33 (delta 4), reused 0 (delta 0), pack-reused 0
# Unpacking objects: 100% (33/33), done.

# %% [markdown]
# ##**Directory access**

# %%
import sys
sys.path.append('/content/ThermodynamicSolutions')

# %% [markdown]
# ##   **Import of the library Thermodynamic Solutions**

# %%
from ThermodynamicSolutions.SolubilityModels import *

# %% [markdown]
# ##   **Installation Google Colaboratory Support**

# %%
# !wget https://github.com/plotly/orca/releases/download/v1.2.1/orca-1.2.1-x86_64.AppImage -O /usr/local/bin/orca
# !chmod +x /usr/local/bin/orca
# !apt-get install xvfb libgtk2.0-0 libgconf-2-4

# %% [markdown]
# ## **Data import**

# %%
data = dataset("https://raw.githubusercontent.com/SolubilityGroup/ThermodynamicSolutions/main/progesterone-data.csv")

# %% [markdown]
# ##  **Solubility Models**

# %%
model = model.modified_apelblat(dataset)

# %%
model.parameters()
# Out:
#      w1          A            B          C      MRD%
# 0   0.0   9.958939 -4876.224792   0.338558 -0.000431
# 1   0.1 -62.817039 -1549.659583  11.179040  0.126947
# 2   0.2   5.339398 -4534.934289   1.002230  0.046903
# 3   0.3 -56.180942 -1718.259580  10.168400  0.157648
# 4   0.4 -70.550028 -1005.545496  12.297415  0.338842
# 5   0.5 -57.395625 -1521.706536  10.319821  0.274856
# 6   0.6  71.023769 -7199.687021  -8.847226 -0.017297
# 7   0.7  29.135516 -5253.746679  -2.615072 -0.111684
# 8   0.8 -12.555870 -3361.219891   3.614433  0.132549
# 9   0.9 -31.075878 -2435.504241   6.346658  0.041146
# 10  1.0  48.333166 -5934.674400  -5.500926 -0.121784

# %%
model.plot()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="606b5d49-f369-4afe-95d0-ce7a28db968a" class="plotly-graph-div" style="height:550px; width:1010px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("606b5d49-f369-4afe-95d0-ce7a28db968a")) {                    Plotly.newPlot(                        "606b5d49-f369-4afe-95d0-ce7a28db968a",                        [{"hovertemplate":"x3_cal: %{x}<br>x3_exp: %{y}<br>T: %{text}<br>","marker":{"line":{"color":"DarkSlateGrey","width":0.5},"size":6},"mode":"markers","name":"w1 =0.0","text":["278.15","283.15","288.15","293.15","298.15","303.15","308.15","313.15","318.15"],"x":[0.003459887374039975,0.004743794411792924,0.006433956583733964,0.008636923642512926,0.011481349689461256,0.015121301522949012,0.01973984095466765,0.025552874669699816,0.03281326186895783],"y":[0.0034744893030838,0.0046994156377213,0.0064341578974239,0.0087582559006953,0.011371975679321,0.015175906924428,0.019610532862175,0.025688827033975,0.032771186669963],"type":"scatter"},{"hovertemplate":"x3_cal: %{x}<br>x3_exp: %{y}<br>T: %{text}<br>","marker":{"line":{"color":"DarkSlateGrey","width":0.5},"size":6},"mode":"markers","name":"w1 =0.1","text":["278.15","283.15","288.15","293.15","298.15","303.15","308.15","313.15","318.15"],"x":[0.004207368010547859,0.005665452589985194,0.0075763810470541775,0.010065145761239144,0.013287082313165756,0.017434262432000584,0.022743035626438972,0.02950289135431377,0.03806683426684443],"y":[0.0041351599457039,0.005635480185674,0.0076505284868274,0.010016323448793,0.013419693986987,0.017438470199934,0.022677140958412,0.02944961961663,0.038109868488973],"type":"scatter"},{"hovertemplate":"x3_cal: %{x}<br>x3_exp: %{y}<br>T: %{text}<br>","marker":{"line":{"color":"DarkSlateGrey","width":0.5},"size":6},"mode":"markers","name":"w1 =0.2","text":["278.15","283.15","288.15","293.15","298.15","303.15","308.15","313.15","318.15"],"x":[0.004874173931919678,0.00661744332350942,0.008892102872166673,0.011832335294274856,0.01559910814637802,0.020384030727911954,0.026413519712743458,0.03395326747624734,0.04331300383116015],"y":[0.0049017272696926,0.0065582496090443,0.0088373959120837,0.011825498584125,0.015642985013814,0.020471522100114,0.026564103247299,0.033627547421016,0.043438571609949],"type":"scatter"},{"hovertemplate":"x3_cal: %{x}<br>x3_exp: %{y}<br>T: %{text}<br>","marker":{"line":{"color":"DarkSlateGrey","width":0.5},"size":6},"mode":"markers","name":"w1 =0.3","text":["278.15","283.15","288.15","293.15","298.15","303.15","308.15","313.15","318.15"],"x":[0.005922428980242154,0.00791685489706806,0.010509550958047852,0.013858805562644001,0.01815938248737361,0.023649721357933518,0.030620328595372743,0.03942351840262628,0.050484679838649335],"y":[0.0057756034693045,0.0078752360811316,0.010590278345737,0.014065568210094,0.018082152251722,0.023677765832405,0.0305503261736,0.039366164004911,0.05053675466131],"type":"scatter"},{"hovertemplate":"x3_cal: %{x}<br>x3_exp: %{y}<br>T: %{text}<br>","marker":{"line":{"color":"DarkSlateGrey","width":0.5},"size":6},"mode":"markers","name":"w1 =0.4","text":["278.15","283.15","288.15","293.15","298.15","303.15","308.15","313.15","318.15"],"x":[0.0070599309141433616,0.009368628362153972,0.012357306431815396,0.01620505120031844,0.021132754945692205,0.027411672329938942,0.0353734906228722,0.045422141429056026,0.05804760968504629],"y":[0.0067681793649336,0.0092907163393141,0.012284524921888,0.016599689146712,0.021238651920961,0.027653662908157,0.035239285139435,0.044884929323543,0.058350313942562],"type":"scatter"},{"hovertemplate":"x3_cal: %{x}<br>x3_exp: %{y}<br>T: %{text}<br>","marker":{"line":{"color":"DarkSlateGrey","width":0.5},"size":6},"mode":"markers","name":"w1 =0.5","text":["278.15","283.15","288.15","293.15","298.15","303.15","308.15","313.15","318.15"],"x":[0.0083555647022 ...

# %%
model.statistics()
# Out:
#   statistic       values
# 0      MRD%     0.078881
# 1      MAPE     0.769924
# 2      RMSD     0.000304
# 3      AICc  1597.513017
# 4        R2     0.999873
# 5      R2_a     0.999744

# %%
model.plot(separated=True)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="c05c0450-aada-4228-a582-300fa7d50f93" class="plotly-graph-div" style="height:1100px; width:1300px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c05c0450-aada-4228-a582-300fa7d50f93")) {                    Plotly.newPlot(                        "c05c0450-aada-4228-a582-300fa7d50f93",                        [{"hovertemplate":"x3_cal: %{x}<br>x3_exp: %{y}<br>T: %{text}<br>","marker":{"line":{"color":"DarkSlateGrey","width":0.5},"size":6},"mode":"markers","name":"","showlegend":false,"text":["278.15","283.15","288.15","293.15","298.15","303.15","308.15","313.15","318.15"],"x":[0.003459887374039975,0.004743794411792924,0.006433956583733964,0.008636923642512926,0.011481349689461256,0.015121301522949012,0.01973984095466765,0.025552874669699816,0.03281326186895783],"y":[0.0034744893030838,0.0046994156377213,0.0064341578974239,0.0087582559006953,0.011371975679321,0.015175906924428,0.019610532862175,0.025688827033975,0.032771186669963],"type":"scatter","xaxis":"x","yaxis":"y"},{"hovertemplate":"x3_cal: %{x}<br>x3_exp: %{y}<br>T: %{text}<br>","marker":{"line":{"color":"DarkSlateGrey","width":0.5},"size":6},"mode":"markers","name":"","showlegend":false,"text":["278.15","283.15","288.15","293.15","298.15","303.15","308.15","313.15","318.15"],"x":[0.004207368010547859,0.005665452589985194,0.0075763810470541775,0.010065145761239144,0.013287082313165756,0.017434262432000584,0.022743035626438972,0.02950289135431377,0.03806683426684443],"y":[0.0041351599457039,0.005635480185674,0.0076505284868274,0.010016323448793,0.013419693986987,0.017438470199934,0.022677140958412,0.02944961961663,0.038109868488973],"type":"scatter","xaxis":"x2","yaxis":"y2"},{"hovertemplate":"x3_cal: %{x}<br>x3_exp: %{y}<br>T: %{text}<br>","marker":{"line":{"color":"DarkSlateGrey","width":0.5},"size":6},"mode":"markers","name":"","showlegend":false,"text":["278.15","283.15","288.15","293.15","298.15","303.15","308.15","313.15","318.15"],"x":[0.004874173931919678,0.00661744332350942,0.008892102872166673,0.011832335294274856,0.01559910814637802,0.020384030727911954,0.026413519712743458,0.03395326747624734,0.04331300383116015],"y":[0.0049017272696926,0.0065582496090443,0.0088373959120837,0.011825498584125,0.015642985013814,0.020471522100114,0.026564103247299,0.033627547421016,0.043438571609949],"type":"scatter","xaxis":"x3","yaxis":"y3"},{"hovertemplate":"x3_cal: %{x}<br>x3_exp: %{y}<br>T: %{text}<br>","marker":{"line":{"color":"DarkSlateGrey","width":0.5},"size":6},"mode":"markers","name":"","showlegend":false,"text":["278.15","283.15","288.15","293.15","298.15","303.15","308.15","313.15","318.15"],"x":[0.005922428980242154,0.00791685489706806,0.010509550958047852,0.013858805562644001,0.01815938248737361,0.023649721357933518,0.030620328595372743,0.03942351840262628,0.050484679838649335],"y":[0.0057756034693045,0.0078752360811316,0.010590278345737,0.014065568210094,0.018082152251722,0.023677765832405,0.0305503261736,0.039366164004911,0.05053675466131],"type":"scatter","xaxis":"x4","yaxis":"y4"},{"hovertemplate":"x3_cal: %{x}<br>x3_exp: %{y}<br>T: %{text}<br>","marker":{"line":{"color":"DarkSlateGrey","width":0.5},"size":6},"mode":"markers","name":"","showlegend":false,"text":["278.15","283.15","288.15","293.15","298.15","303.15","308.15","313.15","318.15"],"x":[0.0070599309141433616,0.009368628362153972,0.012357306431815396,0.01620505120031844,0.021132754945692205,0.027411672329938942,0.0353734906228722,0.045422141429056026,0.05804760968504629],"y":[0.0067681793649336,0.0092907163393141,0.012284524921888,0.016599689146712,0.021238651920961,0.027653662908157,0.035239285139435,0.044884929323543,0.058350313942562],"type":"scatter","xaxis":"x5","yaxis":"y5"},{"hovertemplate":"x3_cal: %{x}<br>x3_exp: %{y}<br>T: %{text}<br>","marker":{"line":{"c ...

# %%
models.statistics(data,403.4,26.9,p0_w=[5, 5, 5, 5, 5, 5])
# Out:
#   statistics  Mod_Apelblat    Vant_Hoff  ...         NRTL       Wilson      Weibull
# 0       MRD%      0.078881     0.002441  ...     0.000985     0.002010     1.890396
# 1       MAPE      0.769924     0.711393  ...     0.348182     0.529780     3.624920
# 2       RMSD      0.000304     0.000359  ...     0.000201     0.000266     0.002289
# 3       AICc   1597.513017  1566.298579  ...  1672.951207  1617.331389  1199.613818
# 4         R2      0.999873     0.999823  ...     0.999945     0.999903     0.992801
# 5       R2_a      0.999744     0.999642  ...     0.999886     0.999800     0.985506
#
# [6 rows x 9 columns]

# %%
models.plots(data,403.4,26.9,p0_w=[5, 5, 5, 5, 5, 5],cols=2, rows=4)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="ba675051-8cd6-4196-8ba6-f2ef9c93a4bb" class="plotly-graph-div" style="height:1000px; width:1300px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("